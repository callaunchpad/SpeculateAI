# %%
import pandas as pd
import matplotlib.pyplot as plt
import csv

# %%
def plot_data(df, title):
    headers = df.columns[1:]
    index = 0
    for i in range(len(headers)):
        header = headers[i]
        y = df[header].tolist()
        y.reverse()
        plt.plot(y)
        plt.xlabel("Day")
        plt.ylabel(header)
        plt.title(title + " " + header)
        plt.show()

# %%
df_DJIA = pd.read_csv("../data/DJIA_table.csv")
df_sp = pd.read_csv("../data/sp500.csv")
plot_data(df_DJIA, "DJ")
plot_data(df_sp, "SP")
